# %%
from langchain_openai import ChatOpenAI

# %%
llm_local = ChatOpenAI(
                    base_url="http://localhost:12434/engines/llama.cpp/v1",
                    model="ai/qwen3:0.6B-F16",
                    temperature=0)

#turn-on docker
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 llm_local = ChatOpenAI(
#       2                     base_url="http://localhost:12434/engines/llama.cpp/v1",
#       3                     model="ai/qwen3:0.6B-F16",
#       4                     temperature=0)
#
# File ~/Downloads/AiDataEngineeringPortfolio/RAG/.venv/lib/python3.12/site-packages/langchain_core/load/serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/Downloads/AiDataEngineeringPortfolio/RAG/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1281, in BaseChatOpenAI.validate_environment(self)
#    1267         self.http_async_client = _build_proxied_async_httpx_client(
#    1268             proxy=self.openai_proxy,
#    1269             verify=global_ssl_context,
#    1270             socket_options=resolved_socket_options,
#    1271         )
#    1272     async_specific = {
#    1273         "http_client": self.http_async_client
#    1274         or _get_default_async_httpx_client(
#    (...)   1279         "api_key": async_api_key_value,
#    1280     }
# -> 1281     self.root_async_client = openai.AsyncOpenAI(
#    1282         **client_params,
#    1283         **async_specific,  # type: ignore[arg-type]
#    1284     )
#    1285     self.async_client = self.root_async_client.chat.completions
#    1286 return self
#
# File ~/Downloads/AiDataEngineeringPortfolio/RAG/.venv/lib/python3.12/site-packages/openai/_client.py:700, in AsyncOpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     691 self.admin_api_key = admin_api_key
#     693 if (
#     694     _enforce_credentials
#     695     and not self.api_key
#    (...)    698     and self.admin_api_key is None
#     699 ):
# --> 700     raise OpenAIError(
#     701         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     702     )
#     704 if organization is None:
#     705     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.

# %%
llm_local.invoke("What is AI?")
# Out:
# AIMessage(content='Artificial Intelligence (AI) refers to the simulation of human intelligence tasks performed by machines. It involves the development of algorithms and models that can learn from data, make decisions, and solve problems. AI is a field of computer science that focuses on creating systems capable of performing tasks that would typically require human intelligence, such as understanding language, recognizing patterns, and making predictions.\n\nAI works by analyzing data, identifying patterns, and learning from past experiences to improve performance over time. This learning process is achieved through machine learning, where models are trained on large datasets to make accurate predictions or decisions. AI has a wide range of applications, including healthcare (diagnosis, personalized treatment), finance (risk assessment, fraud detection), and autonomous systems (self-driving cars, recommendation engines).\n\nAI is not limited to just technology; it is a broad field that continues to evolve and expand in various domains.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 345, 'prompt_tokens': 12, 'total_tokens': 357, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'model.gguf', 'system_fingerprint': 'b1-34ce48d', 'id': 'chatcmpl-vSFfYlRZ652Sx8WXlbkiGI09vvFYacHO', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b1991-1bf5-73b1-8fe4-1b83a82f8705-0', usage_metadata={'input_tokens': 12, 'output_tokens': 345, 'total_tokens': 357, 'input_token_details': {}, 'output_token_details': {}})

# %%
response = llm_local.invoke("What is AI?")
print(response.content)
# Out:
# Artificial Intelligence (AI) refers to the simulation of human intelligence tasks performed by machines. It involves the development of algorithms and models that can learn from data, make decisions, and solve problems. AI is a field of computer science that focuses on creating systems capable of performing tasks that would typically require human intelligence, such as understanding language, recognizing patterns, and making predictions.
#
# AI works by analyzing data, identifying patterns, and learning from past experiences to improve performance over time. This learning process is achieved through machine learning, where models are trained on large datasets to make accurate predictions or decisions. AI has a wide range of applications, including healthcare (diagnosis, personalized treatment), finance (risk assessment, fraud detection), and autonomous systems (self-driving cars, recommendation engines).
#
# AI is not limited to just technology; it is a broad field that spans various domains and continues to evolve rapidly.
