# %%
print("lets go")
# Out:
# lets go

# %%
import sys
print(sys.executable)
# Out:
# /Users/bilal/Downloads/AiDataEngineeringPortfolio/AI/.venv/bin/python

# %% [markdown]
# #create the connection

# %%
import os
print(os.getenv("OPENAI_API_KEY"))
# Out:
# None

# %%
if os.environ.get("OPENAI_API_KEY"):
    print("pass")
else:
    print("Not set")
# Out:
# pass

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# #openai SDK

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5-mini",
    input="i want to learn dimenion and want to understand how dimenion will look of open ai 1536 features or dimension"
)

print(response.output_text)
# Out:
# Good question — “1536 dimensions” refers to an embedding vector with 1536 numeric coordinates (one real number per dimension). These vectors are how OpenAI’s embedding models (e.g., text-embedding-ada-002) represent text in a high-dimensional semantic space. Below is a compact explanation of what that means, how such a vector looks, and practical ways to explore and visualize it.
#
# What a 1536-dimension embedding actually is
# - A 1536-d vector = an array of 1536 floating-point numbers, e.g. [0.023, -0.11, 0.45, ...] (1536 entries).
# - Each coordinate isn’t a human-readable feature like “contains word X.” Instead each dimension is a learned latent feature; combinations of dimensions encode semantic properties.
# - Typical value range depends on the model and scaling; values are usually small floats (roughly around -1 to 1, but not strictly bounded).
#
# Concrete example (truncated)
# - Full vector: [v0, v1, v2, ..., v1535]
# ...

# %% [markdown]
# LLMs basically create the dictionary, each model behave dif and each token is link with token id
#
# i am junaid
# [72, 716, 10891, 1698]
#
# https://platform.openai.com/tokenizer
